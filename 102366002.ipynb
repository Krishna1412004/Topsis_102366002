# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishna1412004/Topsis_102366002/blob/main/102366002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sys

def convert_xlsx_to_csv(excel_file, csv_file):
    data = pd.read_excel('/102366002_data.xlsx')

    data.to_csv(csv_file, index=False)

    print(f"File successfully converted to {csv_file}")

    print(pd.read_csv(csv_file))
convert_xlsx_to_csv("102366002_data.xlsx", "102366002_data.csv")
# Out:
# File successfully converted to 102366002_data.csv
#   Fund Name    P1    P2   P3    P4     P5
# 0        M1  0.84  0.71  6.7  42.1  12.59
# 1        M2  0.91  0.83  7.0  31.7  10.11
# 2        M3  0.79  0.62  4.8  46.7  13.23
# 3        M4  0.78  0.61  6.4  42.4  12.55
# 4        M5  0.94  0.88  3.6  62.2  16.91
# 5        M6  0.88  0.77  6.5  51.5  14.91
# 6        M7  0.66  0.44  5.3  48.9  13.83
# 7        M8  0.93  0.86  3.4  37.0  10.55

# %%
import numpy as np
import pandas as pd

def topsis(input_file, weights, impacts, output_file):
    try:
        if not input_file or not weights or not impacts or not output_file:
            raise ValueError("All parameters (inputFileName, Weights, Impacts, resultFileName) must be provided.")

        if not isinstance(weights, list) or not isinstance(impacts, list):
            raise ValueError("Weights and impacts must be provided as lists separated by commas.")
        if len(weights) != len(impacts):
            raise ValueError("Number of weights and impacts must match.")

        if not all(impact in ['+', '-'] for impact in impacts):
            raise ValueError("Impacts must only contain '+' or '-'.")

        try:
            data = pd.read_csv(input_file)
        except FileNotFoundError:
            raise FileNotFoundError(f"The file '{input_file}' was not found. Please check the file path.")

        print("Initial Dataset:")
        print(data)

        if data.shape[1] < 3:
            raise ValueError("Input file must contain at least three columns (one identifier and at least two criteria).")

        object_names = data.iloc[:, 0]
        numerical_data = data.iloc[:, 1:]

        if not numerical_data.apply(pd.to_numeric, errors='coerce').notnull().all().all():
            raise ValueError("All criteria columns (from the 2nd column onward) must contain numeric values only.")

        if len(weights) != numerical_data.shape[1]:
            raise ValueError("Number of weights must match the number of criteria columns.")

        normalized_data = numerical_data / np.sqrt((numerical_data ** 2).sum())
        print("\nNormalized Data:")
        print(normalized_data)

        weights = np.array(weights, dtype=float)
        weighted_data = normalized_data * weights
        print("\nWeighted Data:")
        print(weighted_data)

        ideal_best = []
        ideal_worst = []
        for i, impact in enumerate(impacts):
            if impact == '+':
                ideal_best.append(weighted_data.iloc[:, i].max())
                ideal_worst.append(weighted_data.iloc[:, i].min())
            else:
                ideal_best.append(weighted_data.iloc[:, i].min())
                ideal_worst.append(weighted_data.iloc[:, i].max())
        print("\nIdeal Best Values:")
        print(ideal_best)
        print("\nIdeal Worst Values:")
        print(ideal_worst)

        distance_best = np.sqrt(((weighted_data - ideal_best) ** 2).sum(axis=1))
        distance_worst = np.sqrt(((weighted_data - ideal_worst) ** 2).sum(axis=1))
        print("\nDistance to Ideal Best:")
        print(distance_best)
        print("\nDistance to Ideal Worst:")
        print(distance_worst)

        scores = distance_worst / (distance_best + distance_worst)
        print("\nTOPSIS Scores:")
        print(scores)

        data['Topsis Score'] = scores
        data['Rank'] = scores.rank(ascending=False).astype(int)
        print("\nFinal Dataset with Scores and Ranks:")
        print(data)

        data.to_csv(output_file, index=False)
        print(f"\nResults successfully saved to {output_file}")

    except ValueError as ve:
        print(f"ValueError: {ve}")
    except FileNotFoundError as fnfe:
        print(f"FileNotFoundError: {fnfe}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

weights = [1, 1, 1, 2, 1]
impacts = ['+', '+', '-', '+', '+']
topsis("102366002_data.csv", weights, impacts, "102366002_result.csv")
# Out:
# Initial Dataset:
#   Fund Name    P1    P2   P3    P4     P5
# 0        M1  0.84  0.71  6.7  42.1  12.59
# 1        M2  0.91  0.83  7.0  31.7  10.11
# 2        M3  0.79  0.62  4.8  46.7  13.23
# 3        M4  0.78  0.61  6.4  42.4  12.55
# 4        M5  0.94  0.88  3.6  62.2  16.91
# 5        M6  0.88  0.77  6.5  51.5  14.91
# 6        M7  0.66  0.44  5.3  48.9  13.83
# 7        M8  0.93  0.86  3.4  37.0  10.55
#
# Normalized Data:
#          P1        P2        P3        P4        P5
# 0  0.351077  0.344401  0.421434  0.322539  0.335992
# 1  0.380334  0.402609  0.440304  0.242862  0.269808
# 2  0.330180  0.300744  0.301923  0.357781  0.353072
# 3  0.326000  0.295893  0.402563  0.324837  0.334925
# 4  0.392872  0.426863  0.226442  0.476530  0.451281
# 5  0.367795  0.373505  0.408854  0.394555  0.397907
# 6  0.275847  0.213431  0.333373  0.374636  0.369084
# 7  0.388693  0.417161  0.213862  0.283467  0.281550
#
# Weighted Data:
#          P1        P2        P3        P4        P5
# 0  0.351077  0.344401  0.421434  0.645078  0.335992
# 1  0.380334  0.402609  0.440304  0.485724  0.269808
# 2  0.330180  0.300744  0.301923  0.715562  0.353072
# 3  0.326000  0.295893  0.402563  0.649675  0.334925
# 4  0.392872  0.426863  0.226442  0.953061  0.451281
# 5  0.367795  0.373505  0.408854  0.789110  0.397907
# 6  0.275847  0.213431  0.333373  0.749271  0.369084
# 7  0.388693  0.417161  0.213862  0.566933  0.281550
#
# Ideal Best Values:
# [0.3928723704909395, 0.42686270006394605, 0.21386185766562923, 0.9530608552257642, 0.45128114237898376]
#
# Ideal Worst Values:
# [0.27584655800427665, 0.21343135003197303, 0.4403038246057073, 0.4857239406857994, 0.2698079449705219]
#
# Distance to Ideal Best:
# 0    0.399722
# 1    0.550779
# 2    0.306009
# 3    0.403503
# 4    0.012580
# 5    0.266883
# 6    0.349023
# 7    0.421918
# dtype: float64
#
# Distance to Ideal Worst:
# 0    0.230093
# 1    0.216115
# 2    0.299138
# 3    0.204597
# 4    0.596926
# 5    0.378840
# 6    0.301243
# 7    0.335036
# dtype: float64
#
# TOPSIS Scores:
# 0    0.365334
# 1    0.281806
# 2    0.494322
# 3    0.336453
# 4    0.979360
# 5    0.586691
# 6    0.463261
# 7    0.442611
# dtype: float64
#
# Final Dataset with Scores and Ranks:
#   Fund Name    P1    P2   P3    P4     P5  Topsis Score  Rank
# 0        M1  0.84  0.71  6.7  42.1  12.59      0.365334     6
# 1        M2  0.91  0.83  7.0  31.7  10.11      0.281806     8
# 2        M3  0.79  0.62  4.8  46.7  13.23      0.494322     3
# 3        M4  0.78  0.61  6.4  42.4  12.55      0.336453     7
# 4        M5  0.94  0.88  3.6  62.2  16.91      0.979360     1
# 5        M6  0.88  0.77  6.5  51.5  14.91      0.586691     2
# 6        M7  0.66  0.44  5.3  48.9  13.83      0.463261     4
# 7        M8  0.93  0.86  3.4  37.0  10.55      0.442611     5
#
# Results successfully saved to 102366002_result.csv
